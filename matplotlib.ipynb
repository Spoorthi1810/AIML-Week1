# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1778, 1779, 1780, 1781, 1782]
y = [85, 68, 80, 75, 69]

plt.plot(x, y, marker='o')
plt.xlabel("Year")
plt.ylabel("Marks")
plt.title("Year vs Marks")

plt.show()

# %%
print(len(x_data))
print(len(y_data))
print(len(x))
print(len(y))
# Out:
# 100
# 100
# 5
# 5

# %%
plt.grid()
plt.scatter(
    x_data,
    y_data,
    color='purple',   
    s=150,            
    marker='*',       
    alpha=0.7
)

# %%
print(x,y)
plt.plot(x,y)
# Out:
# [2006, 2008, 2009, 2010, 2011] [85, 68, 80, 75, 69]

# %%
ages = np.random.normal(28, 2, 1000)   
plt.hist(ages, bins=25)                

print(ages)
plt.show()
# Out:
# [25.20604528 30.33300685 26.03931704 29.37789264 27.36062892 29.90790719
#  27.38432127 26.48814721 26.40066658 29.37778898 28.51123685 28.14398454
#  28.84520214 27.23532611 28.86333158 28.29559175 27.6872016  26.01573603
#  24.40498193 28.35863421 24.94456998 29.16374285 32.24779131 28.85664868
#  31.22584401 24.47820929 28.02949069 28.0979746  25.6292794  29.91424696
#  27.58312956 28.83483248 26.15805264 25.09521529 27.42444678 31.44382164
#  27.09241227 30.53321278 27.35060416 27.21974534 31.1671401  26.38655447
#  28.97781694 30.15496592 26.67194702 27.20911659 31.42620123 28.65447234
#  27.97921394 29.40022579 28.95669838 29.59224129 26.69509118 29.53464355
#  27.58731433 27.42151094 27.35823453 31.05054679 26.82070888 28.41239851
#  32.57079418 29.23664623 25.67907808 29.44893696 26.64332742 28.52768155
#  30.04084577 26.52180717 28.27635906 25.19181205 28.39626012 28.46784432
#  28.46603435 27.91696614 29.19125281 27.88404998 26.62078523 31.12320553
# ...

# %%
langs = ['HTML', 'CSS', 'JavaScript', 'Python', 'SQL', 'React', 'AI']
votes = [30, 25, 45, 70, 40, 55, 80]
colors = ['gold', 'lightblue', 'orange', 'green', 'violet', 'cyan', 'pink']

plt.pie(votes, labels=langs, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title("Technology Preference Distribution")

plt.show()

# %%
x1 = ['Maths', 'Physics', 'Chemistry', 'Biology', 'English', 'CS', 'Economics']
y1 = [65, 70, 55, 60, 75, 85, 68]

plt.bar(x1, y1, color='pink', align="edge", edgecolor="yellow", width=0.5, lw=1)
# Out:
# <BarContainer object of 7 artists>
